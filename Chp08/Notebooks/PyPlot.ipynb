# %%
using PyPlot

# %%
x = collect(range(0.0,stop=2pi,length=1000))
y = sin.(3*x + 4*cos.(2*x));
title("A sinusoidally modulated sinusoid");
plot(x, y, color="red", linewidth=2.0, linestyle="--");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x123b519e8>)

# %%
savefig("sinusoid.svg");

# %%
y = collect(range(0,stop=3π,length=250))
surf(y, y, y .* sin.(y) .* cos.(y)' .* exp.(-0.4y))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x123cc45f8>)
# PyObject <mpl_toolkits.mplot3d.art3d.Poly3DCollection object at 0x12b5b79e8>

# %%
xkcd()
x = collect(range(1, length=101, stop=10));
y = sin.(3x + cos.(5x))
plot(x,y)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x133f051d0>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x132f58c18>
